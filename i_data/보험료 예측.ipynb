# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv('insurance.csv')

# %%
df = df.rename(columns={'sex':'gender'})

# %%
df2 = df[['gender','age','bmi','charges','children','smoker','region']]

# %%
df2
# Out:
#       gender  age     bmi      charges  children  smoker     region
# 0          0   19  27.900  16884.92400         0       1  southwest
# 1          1   18  33.770   1725.55230         1       0  southeast
# 2          1   28  33.000   4449.46200         3       0  southeast
# 3          1   33  22.705  21984.47061         0       0  northwest
# 4          1   32  28.880   3866.85520         0       0  northwest
# ...      ...  ...     ...          ...       ...     ...        ...
# 1333       1   50  30.970  10600.54830         3       0  northwest
# 1334       0   18  31.920   2205.98080         0       0  northeast
# 1335       0   18  36.850   1629.83350         0       0  southeast
# 1336       0   21  25.800   2007.94500         0       0  southwest
# 1337       0   61  29.070  29141.36030         0       1  northwest
#
# [1338 rows x 7 columns]

# %%
df2.columns[:4]
# Out:
# Index(['gender', 'age', 'bmi', 'charges'], dtype='object')

# %%
df2.loc[df['age'] == df2['age'].max(),]
# Out:
#       gender  age     bmi      charges  children  smoker     region
# 62         1   64  24.700  30166.61817         1       0  northwest
# 94         0   64  31.300  47291.05500         2       1  southwest
# 199        0   64  39.330  14901.51670         0       0  northeast
# 328        0   64  33.800  47928.03000         1       1  southwest
# 335        1   64  34.500  13822.80300         0       0  southwest
# 378        0   64  30.115  16455.70785         3       0  northwest
# 398        1   64  25.600  14988.43200         2       0  southwest
# 402        0   64  32.965  14692.66935         0       0  northwest
# 418        1   64  39.160  14418.28040         1       0  southeast
# 420        1   64  33.880  46889.26120         0       1  southeast
# 534        1   64  40.480  13831.11520         0       0  southeast
# 603        0   64  39.050  16085.12750         3       0  southeast
# 635        1   64  38.190  14410.93210         0       0  northeast
# ...

# %%
df2.to_csv('df2.csv',index=False)

# %%
pd.read_csv('df2.csv')
# Out:
#       gender  age     bmi      charges  children  smoker     region
# 0          0   19  27.900  16884.92400         0       1  southwest
# 1          1   18  33.770   1725.55230         1       0  southeast
# 2          1   28  33.000   4449.46200         3       0  southeast
# 3          1   33  22.705  21984.47061         0       0  northwest
# 4          1   32  28.880   3866.85520         0       0  northwest
# ...      ...  ...     ...          ...       ...     ...        ...
# 1333       1   50  30.970  10600.54830         3       0  northwest
# 1334       0   18  31.920   2205.98080         0       0  northeast
# 1335       0   18  36.850   1629.83350         0       0  southeast
# 1336       0   21  25.800   2007.94500         0       0  southwest
# 1337       0   61  29.070  29141.36030         0       1  northwest
#
# [1338 rows x 7 columns]

# %%
df = df.replace('female',0)

# %%
df = df.replace('male',1)

# %%
df
# Out:
#       age  gender     bmi  children smoker     region      charges
# 0      19       0  27.900         0    yes  southwest  16884.92400
# 1      18       1  33.770         1     no  southeast   1725.55230
# 2      28       1  33.000         3     no  southeast   4449.46200
# 3      33       1  22.705         0     no  northwest  21984.47061
# 4      32       1  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50       1  30.970         3     no  northwest  10600.54830
# 1334   18       0  31.920         0     no  northeast   2205.98080
# 1335   18       0  36.850         0     no  southeast   1629.83350
# 1336   21       0  25.800         0     no  southwest   2007.94500
# 1337   61       0  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df = df.replace('yes',1)

# %%
df = df.replace('no',0)

# %%
df.describe()
# Out:
#                age       gender          bmi     children       smoker  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     0.505232    30.663397     1.094918     0.204783
# std      14.049960     0.500160     6.098187     1.205493     0.403694
# min      18.000000     0.000000    15.960000     0.000000     0.000000
# 25%      27.000000     0.000000    26.296250     0.000000     0.000000
# 50%      39.000000     1.000000    30.400000     1.000000     0.000000
# 75%      51.000000     1.000000    34.693750     2.000000     0.000000
# max      64.000000     1.000000    53.130000     5.000000     1.000000
#
#             charges
# count   1338.000000
# mean   13270.422265
# std    12110.011237
# min     1121.873900
# 25%     4740.287150
# 50%     9382.033000
# 75%    16639.912515
# max    63770.428010

# %%
df.loc[df['charges'] == df['charges'].max()]
# Out:
#      age  gender    bmi  children  smoker     region      charges
# 543   54       0  47.41         0       1  southeast  63770.42801

# %%
df.loc[df['charges'] == df['charges'].min()]
# Out:
#      age  gender    bmi  children  smoker     region    charges
# 940   18       1  23.21         0       0  southeast  1121.8739

# %%
plt.hist(data=df , x= 'age', rwidth=0.8, bins=10)
plt.title('Age histogram')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
df.corr()
# Out:
#                age    gender       bmi  children    smoker   charges
# age       1.000000 -0.020856  0.109272  0.042469 -0.025019  0.299008
# gender   -0.020856  1.000000  0.046371  0.017163  0.076185  0.057292
# bmi       0.109272  0.046371  1.000000  0.012759  0.003750  0.198341
# children  0.042469  0.017163  0.012759  1.000000  0.007673  0.067998
# smoker   -0.025019  0.076185  0.003750  0.007673  1.000000  0.787251
# charges   0.299008  0.057292  0.198341  0.067998  0.787251  1.000000

# %%
sb.heatmap(data=df.corr(),annot=True, fmt='.2f',cmap='coolwarm',vmin=-1,vmax=1,linewidths=0.5)
plt.show()

# %%
df.isna().sum()
# Out:
# age         0
# gender      0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.head(3)
# Out:
#    age  gender    bmi  children  smoker     region     charges
# 0   19       0  27.90         0       1  southwest  16884.9240
# 1   18       1  33.77         1       0  southeast   1725.5523
# 2   28       1  33.00         3       0  southeast   4449.4620

# %%
y = df['charges']

# %%
X = df.iloc[:,:4+1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=20)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()

# %%
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(X_test)

# %%
error = y_test - y_pred

# %%
(error**2).mean()
# Out:
# 30880566.62442696

# %%
plt.plot(y_test.values)
plt.plot(y_pred)
plt.legend(['Real','Pred'])
plt.show()

# %%
import joblib

# %%
joblib.dump(regressor,'regressor.pkl')
# Out:
# ['regressor.pkl']
